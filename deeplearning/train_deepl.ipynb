# %% [markdown]
# # Data preparation

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Athletes

# %%
dataset_athlete = pd.read_json('../olympic_athletes.json')
dataset_athlete.head()
dataset_athlete.shape
dataset_athlete.isnull().sum()
# Out:
# athlete_url                 0
# athlete_full_name           0
# games_participations        0
# first_game                 22
# athlete_year_birth       2456
# athlete_medals          60552
# bio                     53062
# dtype: int64

# %% [markdown]
# # Hotes

# %%
dataset_hosts = pd.read_xml('../olympic_hosts.xml')
dataset_hosts.head()
dataset_hosts.shape
dataset_hosts.columns
dataset_hosts.drop(['index'], axis=1, inplace=True)
dataset_hosts.columns
dataset_hosts.isnull().sum()
# Out:
# game_slug          0
# game_end_date      0
# game_start_date    0
# game_location      0
# game_name          0
# game_season        0
# game_year          0
# dtype: int64

# %% [markdown]
# # Medailles

# %%
dataset_medals = pd.read_excel('../olympic_medals.xlsx')
dataset_medals.shape
dataset_medals.isnull().sum()
dataset_medals.duplicated().sum()
dataset_medals.columns
dataset_medals = dataset_medals.rename({'slug_game': 'game_slug'}, axis=1)
dataset_medals.columns
dataset_medals.loc[(dataset_medals.duplicated())]
dataset_medals.loc[(dataset_medals.game_slug == 'paris-1900') & (dataset_medals.discipline_title == 'Polo')]
dataset_medals.loc[(dataset_medals.game_slug == 'london-1908') & (dataset_medals.discipline_title == 'Polo')]
dataset_medals.loc[(dataset_medals.game_slug == 'london-1908') & (dataset_medals.discipline_title == 'Hockey') & (
        dataset_medals.event_title == 'hockey men')]
dataset_medals.participant_title.unique()
dataset_medals.drop(['Unnamed: 0', 'participant_title', 'athlete_url'], axis=1, inplace=True)
dataset_medals.tail()
# Out:
#       discipline_title    game_slug                      event_title  \
# 21692    Weightlifting  athens-1896  heavyweight - one hand lift men
# 21693    Weightlifting  athens-1896  heavyweight - one hand lift men
# 21694    Weightlifting  athens-1896  heavyweight - two hand lift men
# 21695    Weightlifting  athens-1896  heavyweight - two hand lift men
# 21696    Weightlifting  athens-1896  heavyweight - two hand lift men
#
#       event_gender medal_type participant_type        athlete_full_name  \
# 21692          Men     SILVER          Athlete             Viggo JENSEN
# 21693          Men     BRONZE          Athlete  Alexandros Nikolopoulos
# 21694          Men       GOLD          Athlete             Viggo JENSEN
# 21695          Men     SILVER          Athlete        Launceston ELLIOT
# 21696          Men     BRONZE          Athlete          Sotirios VERSIS
#
#         country_name country_code country_3_letter_code
# 21692        Denmark           DK                   DEN
# 21693         Greece           GR                   GRE
# 21694        Denmark           DK                   DEN
# 21695  Great Britain           GB                   GBR
# 21696         Greece           GR                   GRE

# %% [markdown]
# # Results

# %%
dataset_results = pd.read_html('../olympic_results.html')[0]
dataset_results.head()
dataset_results.shape
dataset_results.isnull().sum()
dataset_results.duplicated().sum()
dataset_results.loc[(dataset_results.duplicated())]
dataset_results.value_unit.unique()
dataset_results.value_type.unique()
dataset_results.drop(['Unnamed: 0', 'athlete_url'], axis=1, inplace=True)
dataset_results = dataset_results.rename({'slug_game': 'game_slug'}, axis=1)
dataset_results.columns
# Out:
# Index(['discipline_title', 'event_title', 'game_slug', 'participant_type',
#        'medal_type', 'athletes', 'rank_equal', 'rank_position', 'country_name',
#        'country_code', 'country_3_letter_code', 'athlete_full_name',
#        'value_unit', 'value_type'],
#       dtype='object')

# %% [markdown]
# # Separate winter and summer games

# %%
jo_types = dataset_hosts[['game_slug', 'game_season', 'game_year']]
merged_hosts_results = dataset_results.merge(jo_types, on='game_slug')
merged_hosts_results.head()
merged_hosts_results.shape
merged_hosts_results.game_season.unique()
# Out:
# array(['Winter', 'Summer'], dtype=object)

# %%
summer_games_results = merged_hosts_results.loc[(merged_hosts_results.game_season == 'Summer')].copy()
winter_games_results = merged_hosts_results.loc[(merged_hosts_results.game_season == 'Winter')].copy()

# %%
summer_games_results.drop(['game_season'], axis=1, inplace=True)
summer_games_results.head()
summer_games_results.shape
summer_games_results.isnull().sum()
summer_games_results.duplicated().sum()
dopplers = summer_games_results.loc[(summer_games_results.duplicated())]
dopplers
# Out:
#        discipline_title             event_title       game_slug  \
# 154361       Water Polo        Water Polo Women    antwerp-1920
# 155336          Sailing                8m mixed  stockholm-1912
# 157014         Shooting    trap 125 targets men  stockholm-1912
# 157015         Shooting    trap 125 targets men  stockholm-1912
# 157016         Shooting    trap 125 targets men  stockholm-1912
# ...                 ...                     ...             ...
# 161736          Sailing  Â½-1 Ton Race Two Open      paris-1900
# 161737          Sailing  Â½-1 Ton Race Two Open      paris-1900
# 161738          Sailing  Â½-1 Ton Race Two Open      paris-1900
# 161739          Sailing  Â½-1 Ton Race Two Open      paris-1900
# 162109             Polo                polo men      paris-1900
#
#        participant_type medal_type  \
# 154361         GameTeam        NaN
# 155336         GameTeam        NaN
# 157014          Athlete       GOLD
# 157015          Athlete     SILVER
# 157016          Athlete     BRONZE
# ...                 ...        ...
# 161736         GameTeam        NaN
# 161737         GameTeam        NaN
# 161738         GameTeam        NaN
# 161739         GameTeam        NaN
# 162109         GameTeam     BRONZE
#
#                                                  athletes rank_equal  \
# 154361                                                NaN        NaN
# 155336                                                NaN        NaN
# 157014                                                NaN        NaN
# 157015                                                NaN        NaN
# 157016                                                NaN        NaN
# ...                                                   ...        ...
# 161736  [('LETOT LETOT', 'https://olympics.com/en/athl...        NaN
# 161737  [('LETOT LETOT', 'https://olympics.com/en/athl...        NaN
# 161738  [('LETOT LETOT', 'https://olympics.com/en/athl...        NaN
# 161739  [('LETOT LETOT', 'https://olympics.com/en/athl...        NaN
# 162109                                                NaN        NaN
#
#        rank_position              country_name country_code  \
# 154361             1               Netherlands           NL
# 155336             5        Russian Federation           RU
# 157014             1  United States of America           US
# 157015             2                   Germany           DE
# 157016             3        Russian Federation           RU
# ...              ...                       ...          ...
# 161736           DNF                    France           FR
# 161737           DNF                    France           FR
# 161738           DNF                    France           FR
# 161739           DNF                    France           FR
# 162109             3                       MIX          NaN
#
#        country_3_letter_code athlete_full_name value_unit value_type  \
# 154361                   NED               NaN          2      SCORE
# 155336                   RUS               NaN          0     POINTS
# 157014                   USA        Jay Graham         96     POINTS
# 157015                   GER    Alfred GOELDEL         94     POINTS
# 157016                   RUS       Harry Blaus         91     POINTS
# ...                      ...               ...        ...        ...
# 161736                   FRA               NaN        NaN        IRM
# 161737                   FRA               NaN        NaN        IRM
# 161738                   FRA               NaN        NaN        IRM
# 161739                   FRA               NaN        NaN        IRM
# 162109                   MIX               NaN        NaN        NaN
#
#         game_year
# 154361       1920
# 155336       1912
# 157014       1912
# 157015       1912
# 157016       1912
# ...           ...
# 161736       1900
# 161737       1900
# 161738       1900
# 161739       1900
# 162109       1900
#
# [112 rows x 15 columns]

# %% [markdown]
# # Calculate the total number of each type of medals for each games by country

# %%
summer_games_results.medal_type.unique()
summer_games_results['medal_type'] = summer_games_results['medal_type'].fillna('None')
summer_games_results['total_medals'] = summer_games_results['medal_type'].apply(lambda x: 0 if x == 'None' else 1)
summer_games_results['gold_medals'] = summer_games_results['medal_type'].apply(lambda x: 1 if x == 'GOLD' else 0)
summer_games_results['silver_medals'] = summer_games_results['medal_type'].apply(lambda x: 1 if x == 'SILVER' else 0)
summer_games_results['bronze_medals'] = summer_games_results['medal_type'].apply(lambda x: 1 if x == 'BRONZE' else 0)
summer_games_results
summer_games_results.country_name.unique()
historic_medalsbycountry = summer_games_results.groupby(['game_year', 'country_name']).agg(
    {'total_medals': 'sum', 'gold_medals': 'sum', 'silver_medals': 'sum', 'bronze_medals': 'sum'})
historic_medalsbycountry = historic_medalsbycountry.sort_values(by=['game_year', 'total_medals'],
                                                                ascending=[True, False]).reset_index()
historic_medalsbycountry
# Out:
#       game_year              country_name  total_medals  gold_medals  \
# 0          1896                    Greece            47           10
# 1          1896  United States of America            20           11
# 2          1896                   Germany            13            6
# 3          1896                    France            11            5
# 4          1896             Great Britain             7            2
# ...         ...                       ...           ...          ...
# 2884       2020   Virgin Islands, British             0            0
# 2885       2020        Virgin Islands, US             0            0
# 2886       2020                     Yemen             0            0
# 2887       2020                    Zambia             0            0
# 2888       2020                  Zimbabwe             0            0
#
#       silver_medals  bronze_medals
# 0                18             19
# 1                 7              2
# 2                 5              2
# 3                 4              2
# 4                 3              2
# ...             ...            ...
# 2884              0              0
# 2885              0              0
# 2886              0              0
# 2887              0              0
# 2888              0              0
#
# [2889 rows x 6 columns]

# %% [markdown]
# # Calculate the total number of disciplines for each games by country

# %%
historic_sportsbycountry = summer_games_results.groupby(['game_year', 'country_name', 'discipline_title']).count()
historic_sportsbycountry
historic_sportsbycountry = historic_sportsbycountry[['event_title']].reset_index()
historic_sportsbycountry = historic_sportsbycountry.rename({'discipline_title': 'sports', 'event_title': 'epreuves'},
                                                           axis=1)
historic_sportsbycountry
historic_sportsbycountry = historic_sportsbycountry.groupby(['game_year', 'country_name']).agg({'sports': 'count'})
historic_sportsbycountry = historic_sportsbycountry.reset_index()
historic_sportsbycountry
historic_epreuvesbycountry = summer_games_results.groupby(['game_year', 'country_name', 'event_title']).count()
historic_epreuvesbycountry

historic_epreuvesbycountry = historic_epreuvesbycountry[['discipline_title']].reset_index()
historic_epreuvesbycountry = historic_epreuvesbycountry.rename(
    {'event_title': 'epreuves', 'discipline_title': 'participation'}, axis=1)
historic_epreuvesbycountry = historic_epreuvesbycountry.groupby(['game_year', 'country_name']).agg(
    {'epreuves': 'count'})
historic_epreuvesbycountry = historic_epreuvesbycountry.reset_index()
historic_epreuvesbycountry
historic_olympic_data = historic_medalsbycountry.merge(historic_sportsbycountry, on=['game_year', 'country_name'])
historic_olympic_data = historic_olympic_data.merge(historic_epreuvesbycountry, on=['game_year', 'country_name'])
historic_olympic_data = historic_olympic_data.sort_values(by=['game_year', 'total_medals'], ascending=[True, False])
historic_olympic_data
# Out:
#       game_year              country_name  total_medals  gold_medals  \
# 0          1896                    Greece            47           10
# 1          1896  United States of America            20           11
# 2          1896                   Germany            13            6
# 3          1896                    France            11            5
# 4          1896             Great Britain             7            2
# ...         ...                       ...           ...          ...
# 2884       2020   Virgin Islands, British             0            0
# 2885       2020        Virgin Islands, US             0            0
# 2886       2020                     Yemen             0            0
# 2887       2020                    Zambia             0            0
# 2888       2020                  Zimbabwe             0            0
#
#       silver_medals  bronze_medals  sports  epreuves
# 0                18             19      10        39
# 1                 7              2       3        17
# 2                 5              2       7        27
# 3                 4              2       7        20
# 4                 3              2       9        20
# ...             ...            ...     ...       ...
# 2884              0              0       1         2
# 2885              0              0       1         1
# 2886              0              0       2         2
# 2887              0              0       3         5
# 2888              0              0       2         2
#
# [2889 rows x 8 columns]

# %%
game_part = summer_games_results.groupby(['country_name', 'game_year']).agg(
    {'total_medals': 'sum', 'gold_medals': 'sum', 'silver_medals': 'sum', 'bronze_medals': 'sum'})
game_part
game_p = game_part.reset_index()
game_p_france = game_p.loc[(game_p.country_name == 'France')]
game_p_france
import warnings

warnings.filterwarnings('ignore')
game_p_france = game_p.loc[(game_p.country_name == 'France')]
game_p_france['game_part'] = range(0, game_p_france.shape[0])
game_p_france['prec_game_medal'] = game_p_france['total_medals'].shift(1, fill_value=0)
game_p_france['prec_game_gold'] = game_p_france['gold_medals'].shift(1, fill_value=0)
game_p_france['prec_game_silver'] = game_p_france['silver_medals'].shift(1, fill_value=0)
game_p_france['prec_game_bronze'] = game_p_france['bronze_medals'].shift(1, fill_value=0)
game_p_france
game_p
liste_country = list(game_p.country_name.unique())
liste_country.remove('France')
liste_country
for country in liste_country:
    game_p_temp = game_p.loc[(game_p.country_name == country)]
    game_p_temp['game_part'] = range(0, game_p_temp.shape[0])
    game_p_temp['prec_game_medal'] = game_p_temp['total_medals'].shift(1, fill_value=0)
    game_p_temp['prec_game_gold'] = game_p_temp['gold_medals'].shift(1, fill_value=0)
    game_p_temp['prec_game_silver'] = game_p_temp['silver_medals'].shift(1, fill_value=0)
    game_p_temp['prec_game_bronze'] = game_p_temp['bronze_medals'].shift(1, fill_value=0)
    game_p_france = pd.concat([game_p_france, game_p_temp])
game_p_france.columns
game_p_france = game_p_france[
    ['game_year', 'country_name', 'total_medals', 'gold_medals', 'silver_medals', 'bronze_medals', 'game_part',
     'prec_game_medal', 'prec_game_gold', 'prec_game_silver', 'prec_game_bronze']]
game_p_france = game_p_france.sort_values(by=['game_year', 'total_medals'], ascending=[True, False])
game_p_france
game_p_france = game_p_france[
    ['game_year', 'country_name', 'game_part', 'prec_game_medal', 'prec_game_gold', 'prec_game_silver',
     'prec_game_bronze']]
game_p_france
historic_olympic_data = pd.merge(historic_olympic_data, game_p_france, on=['game_year', 'country_name'])

historic_olympic_data = historic_olympic_data.sort_values(by=['game_year', 'total_medals'], ascending=[True, False])

# %% [markdown]
# # Save the data to ../csv/olympic_data_cleaned.csv

# %%
historic_olympic_data.to_csv('../csv/olympic_data_cleaned.csv', index=False)

# %% [markdown]
# ## Train Dense Neural Network

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import tensorflow as tf
from keras import models, layers
import joblib

# %%
# Load data
historic_olympic_data = pd.read_csv('../csv/olympic_data_cleaned.csv')

# Split data before 2020
data_before_2020 = historic_olympic_data[historic_olympic_data['game_year'] < 2020]
data_2020 = historic_olympic_data[historic_olympic_data['game_year'] == 2020]

# Features and target variables
features = ['sports', 'epreuves', 'game_part', 'prec_game_medal', 'prec_game_gold', 'prec_game_silver', 'prec_game_bronze']
target = ['gold_medals', 'silver_medals', 'bronze_medals']

# Define the number of epochs and batch size
epochs = 130
batch_size = 32

# Split features and targets
X_train = data_before_2020[features]
y_train = data_before_2020[target]
X_test = data_2020[features]
y_test = data_2020[target]
countries_2020 = data_2020['country_name']

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build the dense neural network model
model_dense = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train_scaled.shape[1],)),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(3) # Output layer for gold, silver, and bronze medals
])

# Compile the model
model_dense.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model
history_dense = model_dense.fit(X_train_scaled, y_train, epochs=epochs, batch_size=batch_size, validation_split=0.2, verbose=1)

# Evaluate the model
loss_dense, mae_dense = model_dense.evaluate(X_test_scaled, y_test, verbose=0)

# Make predictions
y_pred_dense = model_dense.predict(X_test_scaled)

# Calculate additional metrics
mse_dense = mean_squared_error(y_test, y_pred_dense)
mae_dense = mean_absolute_error(y_test, y_pred_dense)
r2_dense = r2_score(y_test, y_pred_dense)

print(f'Dense Neural Network - Mean Squared Error: {mse_dense}')
print(f'Dense Neural Network - Mean Absolute Error: {mae_dense}')
print(f'Dense Neural Network - R-squared: {r2_dense}')

# Combine results into a DataFrame for easier comparison
results_dense = pd.DataFrame({
    'Country': countries_2020,
    'Actual Gold': y_test['gold_medals'],
    'Actual Silver': y_test['silver_medals'],
    'Actual Bronze': y_test['bronze_medals'],
    'Predicted Gold': y_pred_dense[:, 0],
    'Predicted Silver': y_pred_dense[:, 1],
    'Predicted Bronze': y_pred_dense[:, 2]
})

# Display the results
print(results_dense)

# Save the scaler
joblib.dump(scaler, '../models/olympic_medals_scaler.pkl')
# Out:
# Epoch 1/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 33.1937 - mae: 1.8276 - val_loss: 3.8904 - val_mae: 0.9763
# Epoch 2/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.4909 - mae: 1.2558 - val_loss: 2.2660 - val_mae: 0.6369
# Epoch 3/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 12.0635 - mae: 1.1473 - val_loss: 2.0698 - val_mae: 0.6237
# Epoch 4/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.5840 - mae: 1.1972 - val_loss: 2.1113 - val_mae: 0.6287
# Epoch 5/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.1083 - mae: 1.2050 - val_loss: 2.2454 - val_mae: 0.6549
# Epoch 6/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 13.0420 - mae: 1.1783 - val_loss: 2.3296 - val_mae: 0.6588
# Epoch 7/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9037 - mae: 1.0678 - val_loss: 2.4106 - val_mae: 0.6788
# Epoch 8/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2204 - mae: 1.0883 - val_loss: 2.4298 - val_mae: 0.6330
# Epoch 9/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.7460 - mae: 1.1189 - val_loss: 2.3446 - val_mae: 0.6347
# Epoch 10/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0234 - mae: 1.0806 - val_loss: 2.5196 - val_mae: 0.7009
# Epoch 11/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6601 - mae: 1.0801 - val_loss: 2.5306 - val_mae: 0.7341
# Epoch 12/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5303 - mae: 1.1001 - val_loss: 2.6928 - val_mae: 0.7963
# Epoch 13/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.3557 - mae: 0.9794 - val_loss: 2.6855 - val_mae: 0.6787
# Epoch 14/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5374 - mae: 1.0560 - val_loss: 2.3662 - val_mae: 0.6397
# Epoch 15/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6656 - mae: 0.9685 - val_loss: 2.2323 - val_mae: 0.6481
# Epoch 16/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3926 - mae: 1.0846 - val_loss: 2.3140 - val_mae: 0.6384
# Epoch 17/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.5137 - mae: 1.0386 - val_loss: 2.1951 - val_mae: 0.6084
# Epoch 18/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6204 - mae: 0.9322 - val_loss: 2.5490 - val_mae: 0.6788
# Epoch 19/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.3629 - mae: 1.0594 - val_loss: 2.2456 - val_mae: 0.6402
# Epoch 20/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5158 - mae: 1.0104 - val_loss: 2.5828 - val_mae: 0.6211
# Epoch 21/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3068 - mae: 1.0177 - val_loss: 2.6938 - val_mae: 0.6511
# Epoch 22/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0498 - mae: 1.0636 - val_loss: 2.5106 - val_mae: 0.6621
# Epoch 23/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6609 - mae: 1.0530 - val_loss: 2.2767 - val_mae: 0.5998
# Epoch 24/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.5106 - mae: 0.9881 - val_loss: 2.1109 - val_mae: 0.5894
# Epoch 25/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8192 - mae: 1.0251 - val_loss: 2.2223 - val_mae: 0.5978
# Epoch 26/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4587 - mae: 1.0177 - val_loss: 2.2737 - val_mae: 0.6080
# Epoch 27/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1047 - mae: 1.0745 - val_loss: 2.2644 - val_mae: 0.6299
# Epoch 28/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.3485 - mae: 1.0464 - val_loss: 2.0540 - val_mae: 0.6021
# Epoch 29/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9043 - mae: 0.9383 - val_loss: 2.1802 - val_mae: 0.5801
# Epoch 30/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 10.1127 - mae: 1.0237 - val_loss: 2.0214 - val_mae: 0.5774
# Epoch 31/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11.2928 - mae: 1.1396 - val_loss: 1.9531 - val_mae: 0.5882
# Epoch 32/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.0485 - mae: 0.9673 - val_loss: 2.1857 - val_mae: 0.5969
# Epoch 33/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9516 - mae: 0.9931 - val_loss: 2.2544 - val_mae: 0.5880
# Epoch 34/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9823 - mae: 1.0602 - val_loss: 1.9591 - val_mae: 0.5828
# Epoch 35/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2889 - mae: 1.0205 - val_loss: 2.0690 - val_mae: 0.5799
# Epoch 36/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0028 - mae: 1.0101 - val_loss: 2.0740 - val_mae: 0.5930
# Epoch 37/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4487 - mae: 1.0232 - val_loss: 2.1275 - val_mae: 0.5826
# Epoch 38/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 11.4816 - mae: 1.0225 - val_loss: 2.1373 - val_mae: 0.6145
# Epoch 39/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2421 - mae: 1.0170 - val_loss: 2.1305 - val_mae: 0.6407
# Epoch 40/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7271 - mae: 1.0090 - val_loss: 2.2160 - val_mae: 0.6116
# Epoch 41/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6811 - mae: 0.9802 - val_loss: 2.2131 - val_mae: 0.6186
# Epoch 42/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9044 - mae: 0.9703 - val_loss: 2.1802 - val_mae: 0.6179
# Epoch 43/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.7394 - mae: 1.0683 - val_loss: 2.0979 - val_mae: 0.5910
# Epoch 44/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5474 - mae: 0.9971 - val_loss: 2.3857 - val_mae: 0.6126
# Epoch 45/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9441 - mae: 0.9505 - val_loss: 2.6706 - val_mae: 0.6303
# Epoch 46/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6320 - mae: 1.0512 - val_loss: 2.2635 - val_mae: 0.5933
# Epoch 47/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.5188 - mae: 0.9830 - val_loss: 2.2259 - val_mae: 0.6172
# Epoch 48/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3810 - mae: 0.9875 - val_loss: 2.3053 - val_mae: 0.5877
# Epoch 49/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4474 - mae: 0.9177 - val_loss: 2.4219 - val_mae: 0.6097
# Epoch 50/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.3602 - mae: 0.9578 - val_loss: 2.3707 - val_mae: 0.6030
# Epoch 51/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.4206 - mae: 0.9917 - val_loss: 2.6092 - val_mae: 0.6347
# Epoch 52/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6698 - mae: 1.0498 - val_loss: 2.2763 - val_mae: 0.5909
# Epoch 53/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5063 - mae: 0.9729 - val_loss: 2.3604 - val_mae: 0.6069
# Epoch 54/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4412 - mae: 1.0208 - val_loss: 2.6912 - val_mae: 0.6202
# Epoch 55/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.5182 - mae: 1.0253 - val_loss: 2.2645 - val_mae: 0.5941
# Epoch 56/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8529 - mae: 0.9253 - val_loss: 2.6103 - val_mae: 0.6164
# Epoch 57/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0732 - mae: 1.0114 - val_loss: 2.4233 - val_mae: 0.5947
# Epoch 58/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3392 - mae: 0.8795 - val_loss: 2.5632 - val_mae: 0.6147
# Epoch 59/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6774 - mae: 0.9473 - val_loss: 2.5042 - val_mae: 0.6129
# Epoch 60/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.3093 - mae: 1.0467 - val_loss: 2.3122 - val_mae: 0.6162
# Epoch 61/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.7228 - mae: 1.0027 - val_loss: 2.3718 - val_mae: 0.6094
# Epoch 62/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2053 - mae: 1.0170 - val_loss: 2.4638 - val_mae: 0.5972
# Epoch 63/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.9342 - mae: 1.0267 - val_loss: 2.4218 - val_mae: 0.6061
# Epoch 64/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7171 - mae: 1.0103 - val_loss: 2.4260 - val_mae: 0.6086
# Epoch 65/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0546 - mae: 0.9606 - val_loss: 2.3864 - val_mae: 0.6017
# Epoch 66/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6771 - mae: 1.0791 - val_loss: 2.4495 - val_mae: 0.6058
# Epoch 67/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4258 - mae: 0.9758 - val_loss: 2.5742 - val_mae: 0.6288
# Epoch 68/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7387 - mae: 0.9386 - val_loss: 2.9090 - val_mae: 0.6390
# Epoch 69/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.7457 - mae: 0.9466 - val_loss: 2.4966 - val_mae: 0.6179
# Epoch 70/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8931 - mae: 1.0526 - val_loss: 2.3858 - val_mae: 0.6421
# Epoch 71/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5368 - mae: 0.9267 - val_loss: 2.6126 - val_mae: 0.6065
# Epoch 72/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.3057 - mae: 0.9730 - val_loss: 2.5914 - val_mae: 0.6231
# Epoch 73/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6041 - mae: 0.9836 - val_loss: 2.3737 - val_mae: 0.6342
# Epoch 74/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5623 - mae: 0.9530 - val_loss: 2.5985 - val_mae: 0.6309
# Epoch 75/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.1424 - mae: 0.9898 - val_loss: 2.8532 - val_mae: 0.6574
# Epoch 76/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.2934 - mae: 1.0046 - val_loss: 2.5756 - val_mae: 0.6128
# Epoch 77/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4978 - mae: 0.9818 - val_loss: 2.7673 - val_mae: 0.6304
# Epoch 78/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2766 - mae: 0.9463 - val_loss: 2.4931 - val_mae: 0.6421
# Epoch 79/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2941 - mae: 0.9782 - val_loss: 2.8459 - val_mae: 0.6145
# Epoch 80/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5012 - mae: 0.9531 - val_loss: 2.9865 - val_mae: 0.6033
# Epoch 81/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.0487 - mae: 0.9627 - val_loss: 2.6826 - val_mae: 0.6357
# Epoch 82/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8874 - mae: 0.9435 - val_loss: 2.7108 - val_mae: 0.6205
# Epoch 83/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8614 - mae: 0.9495 - val_loss: 2.7837 - val_mae: 0.6728
# Epoch 84/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7893 - mae: 1.0452 - val_loss: 2.8055 - val_mae: 0.6162
# Epoch 85/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0745 - mae: 0.9975 - val_loss: 2.6762 - val_mae: 0.6092
# Epoch 86/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5140 - mae: 0.9013 - val_loss: 3.1761 - val_mae: 0.6542
# Epoch 87/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7456 - mae: 0.9516 - val_loss: 2.9714 - val_mae: 0.6134
# Epoch 88/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9959 - mae: 0.9992 - val_loss: 2.5603 - val_mae: 0.6413
# Epoch 89/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2877 - mae: 0.9220 - val_loss: 3.0665 - val_mae: 0.6406
# Epoch 90/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.7932 - mae: 0.9979 - val_loss: 2.8340 - val_mae: 0.6448
# Epoch 91/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.1848 - mae: 0.9282 - val_loss: 2.8373 - val_mae: 0.6127
# Epoch 92/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6811 - mae: 0.9929 - val_loss: 2.7088 - val_mae: 0.6110
# Epoch 93/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8291 - mae: 0.9863 - val_loss: 2.7347 - val_mae: 0.6121
# Epoch 94/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5909 - mae: 0.9215 - val_loss: 2.7824 - val_mae: 0.6075
# Epoch 95/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8022 - mae: 0.8813 - val_loss: 3.3458 - val_mae: 0.6568
# Epoch 96/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0792 - mae: 0.9008 - val_loss: 2.9024 - val_mae: 0.6645
# Epoch 97/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.3472 - mae: 0.9909 - val_loss: 2.5811 - val_mae: 0.6128
# Epoch 98/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9343 - mae: 0.9241 - val_loss: 2.7032 - val_mae: 0.6121
# Epoch 99/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0559 - mae: 0.9942 - val_loss: 2.6533 - val_mae: 0.6115
# Epoch 100/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9686 - mae: 0.9563 - val_loss: 2.8271 - val_mae: 0.6065
# Epoch 101/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0520 - mae: 0.9474 - val_loss: 3.0833 - val_mae: 0.6035
# Epoch 102/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.8237 - mae: 0.9533 - val_loss: 2.6611 - val_mae: 0.6258
# Epoch 103/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8975 - mae: 0.9394 - val_loss: 2.8872 - val_mae: 0.6983
# Epoch 104/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6410 - mae: 1.0541 - val_loss: 3.1056 - val_mae: 0.6062
# Epoch 105/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4508 - mae: 0.9063 - val_loss: 2.8299 - val_mae: 0.6409
# Epoch 106/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9666 - mae: 0.9559 - val_loss: 2.9594 - val_mae: 0.6304
# Epoch 107/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5984 - mae: 0.9665 - val_loss: 3.1669 - val_mae: 0.6295
# Epoch 108/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5076 - mae: 0.9473 - val_loss: 3.1877 - val_mae: 0.6348
# Epoch 109/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6010 - mae: 0.9045 - val_loss: 2.9252 - val_mae: 0.6264
# Epoch 110/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.1314 - mae: 1.0275 - val_loss: 2.9003 - val_mae: 0.6572
# Epoch 111/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0147 - mae: 0.9057 - val_loss: 3.1028 - val_mae: 0.6172
# Epoch 112/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0404 - mae: 0.9638 - val_loss: 3.1733 - val_mae: 0.6523
# Epoch 113/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2825 - mae: 0.9101 - val_loss: 3.8693 - val_mae: 0.6971
# Epoch 114/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.3742 - mae: 0.9679 - val_loss: 2.7510 - val_mae: 0.6349
# Epoch 115/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.1273 - mae: 0.9624 - val_loss: 2.9617 - val_mae: 0.6260
# Epoch 116/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8568 - mae: 0.9946 - val_loss: 2.6179 - val_mae: 0.6023
# Epoch 117/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4831 - mae: 0.9347 - val_loss: 2.4877 - val_mae: 0.6163
# Epoch 118/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6282 - mae: 1.0286 - val_loss: 2.4940 - val_mae: 0.5899
# Epoch 119/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.1215 - mae: 0.9372 - val_loss: 2.8313 - val_mae: 0.6353
# Epoch 120/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3725 - mae: 0.8894 - val_loss: 3.1166 - val_mae: 0.6291
# Epoch 121/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4018 - mae: 0.9646 - val_loss: 2.7645 - val_mae: 0.6304
# Epoch 122/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2066 - mae: 0.9024 - val_loss: 3.0780 - val_mae: 0.6451
# Epoch 123/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1511 - mae: 0.9336 - val_loss: 3.0258 - val_mae: 0.6927
# Epoch 124/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6753 - mae: 0.9503 - val_loss: 3.0780 - val_mae: 0.6124
# Epoch 125/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.3277 - mae: 0.9961 - val_loss: 2.7001 - val_mae: 0.6426
# Epoch 126/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8827 - mae: 0.9639 - val_loss: 2.7917 - val_mae: 0.6163
# Epoch 127/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5204 - mae: 0.8393 - val_loss: 3.2090 - val_mae: 0.6428
# Epoch 128/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.3030 - mae: 0.9427 - val_loss: 3.1835 - val_mae: 0.6629
# Epoch 129/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1645 - mae: 0.9038 - val_loss: 3.2253 - val_mae: 0.6365
# Epoch 130/130
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0754 - mae: 0.9240 - val_loss: 2.7373 - val_mae: 0.6176
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Dense Neural Network - Mean Squared Error: 5.373745637852814
# Dense Neural Network - Mean Absolute Error: 0.8943638729617783
# Dense Neural Network - R-squared: 0.7883502840995789
#                          Country  Actual Gold  Actual Silver  Actual Bronze  \
# 2699    United States of America           39             41             33
# 2700  People's Republic of China           38             32             18
# 2701                         ROC           20             28             22
# 2702               Great Britain           22             21             22
# 2703                       Japan           27             13             17
# ...                          ...          ...            ...            ...
# 2884     Virgin Islands, British            0              0              0
# 2885          Virgin Islands, US            0              0              0
# 2886                       Yemen            0              0              0
# 2887                      Zambia            0              0              0
# 2888                    Zimbabwe            0              0              0
#
#       Predicted Gold  Predicted Silver  Predicted Bronze
# 2699       38.404938         33.546135         31.252712
# 2700       15.882952         15.062125         18.200239
# 2701       43.894398         38.802170         30.286493
# 2702       21.031069         17.533173         16.772886
# 2703       10.576074         11.849901         12.782753
# ...              ...               ...               ...
# 2884        0.011582          0.006803          0.020804
# 2885       -0.003779         -0.003409          0.014391
# 2886        0.001328          0.015302          0.135921
# 2887        0.077822         -0.009062          0.062124
# 2888        0.051322         -0.041370          0.017285
#
# [190 rows x 7 columns]
# ['../models/olympic_medals_scaler.pkl']

# %%
# Save the DNN model to ../models/olympic_medals_dnn.h5
model_dense.save('../models/olympic_medals_dnn.h5')
model_dense.save('../models/olympic_medals_dnn.keras')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ['../models/olympic_medals_scaler.pkl']
